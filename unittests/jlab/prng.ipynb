# %%
import numpy as np
from scipy.stats import binom as bn

# %matplotlib ipympl
import matplotlib.pyplot as plt

import csv

# %%
nTrials = 2**8
kSuccesses = 128
assumedProb = 0.5
bn.cdf(kSuccesses, nTrials, assumedProb)
# Out:
# 0.5249095549680697

# %%
x = np.arange(25 + 1)
y = np.square(x)
plt.plot(x, y)
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
x = np.array([50,60,60,70,50, 100])
x.std()
# Out:
# 17.07825127659933
